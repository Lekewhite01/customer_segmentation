# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# Read labelled data into pandas dataframe
df = pd.read_csv("./output/labelled_data.csv")

# %%
df.head()
# Out:
#                  customer_unique_id                          order_id  \
# 0  7c396fd4830fd04220f754e42b4e5bff  e481f51cbdc54678b7cc49136f2d6af7
# 1  7c396fd4830fd04220f754e42b4e5bff  e481f51cbdc54678b7cc49136f2d6af7
# 2  7c396fd4830fd04220f754e42b4e5bff  e481f51cbdc54678b7cc49136f2d6af7
# 3  3a51803cc0d012c3b5dc8b7528cb05f7  128e10d95713541c87cd1a2e48201934
# 4  ef0996a1a279c26e7ecbd737be23d235  0e7e841ddf8f8f2de2bad69267ecfbcf
#
#   order_status order_purchase_timestamp  customer_zip_code_prefix  \
# 0    delivered      2017-10-02 10:56:33                      3149
# 1    delivered      2017-10-02 10:56:33                      3149
# 2    delivered      2017-10-02 10:56:33                      3149
# 3    delivered      2017-08-15 18:29:31                      3366
# 4    delivered      2017-08-02 18:24:47                      2290
#
#   customer_city customer_state  price  freight_value  payment_sequential  \
# ...

# %% [markdown]
# ## Cluster 0

# %%
# Subset the dataframe to just `cluster 0` profiles
cluster_0_df = df[df["clusters"]==0]
cluster_0_df.head()
# Out:
#                   customer_unique_id                          order_id  \
# 12  1bcb517dc3cc80868d2fa941174f386c  a3bf941183211246f0d42ad757cba127
# 18  8b8d696df5beff17e7cfef915f0d1d78  1f201b2bf1eecbd0ad32c3f430846b84
# 19  a6b38dcfe711532c6f588ca185770b2d  84aaa1a774e37a0a7c1a5413dc49e168
# 22  c6eefe8e9d3cd8a9ef18730a674d9add  f37bdf37547266e7d6760e52bc87dfe3
# 23  c6eefe8e9d3cd8a9ef18730a674d9add  f37bdf37547266e7d6760e52bc87dfe3
#
#    order_status order_purchase_timestamp  customer_zip_code_prefix  \
# 12    delivered      2017-07-24 22:16:25                      6298
# 18    delivered      2017-09-26 21:32:17                      5782
# 19    delivered      2017-07-21 10:03:34                      5417
# 22    delivered      2017-07-25 16:49:56                      2261
# 23    delivered      2017-07-25 16:49:56                      2261
#
#    customer_city customer_state  price  freight_value  payment_sequential  \
# ...

# %%
customers =cluster_0_df["customer_unique_id"].nunique()
print("Number of customers in the Cluster 0:", customers)
# Out:
# Number of customers in the Cluster 0: 32672
